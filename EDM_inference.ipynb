# %%
import torch, os
import torch.nn.functional as F
from math import sqrt
import lightning as pl
from einops import rearrange
import matplotlib.pyplot as plt
from tqdm import tqdm
from einops import rearrange

from torchvision.utils import save_image, make_grid
from torchvision import transforms
from torchvision.datasets import MNIST

from modules.trainers.EDM import EDM

# %%
model = EDM.load_from_checkpoint('/home/exouser/genmod/genmod/rdipk0yl/checkpoints/last.ckpt')
model.eval()
print('num timesteps - ', model.n_T)
# Out:
# num timesteps -  50

# %%
device = "cuda:0"

torch.cuda.empty_cache()

model = model.to(device)

gen_imgs = []
for _ in range(9):
    x_T = torch.randn((1,1,28,28)).to(device)  # x_T ~ N(0, 1), sample initial noise
    x_0 = model.reverse_diffusion_process(x_T)

    gen_imgs.append(x_0.squeeze(0).detach().cpu())
    
gen_imgs = rearrange(gen_imgs, 'b c h w -> b c h w')
# create grid
grid = make_grid(gen_imgs, nrow=3, padding=2)

# plot grid
plt.imshow(grid.permute(1, 2, 0))
plt.axis('off')
plt.show()
# Out:
# sampling time step: 100%|██████████| 50/50 [00:00<00:00, 51.42it/s]
# sampling time step: 100%|██████████| 50/50 [00:00<00:00, 156.84it/s]
# sampling time step: 100%|██████████| 50/50 [00:00<00:00, 157.05it/s]
# sampling time step: 100%|██████████| 50/50 [00:00<00:00, 154.60it/s]
# sampling time step: 100%|██████████| 50/50 [00:00<00:00, 154.87it/s]
# sampling time step: 100%|██████████| 50/50 [00:00<00:00, 154.63it/s]
# sampling time step: 100%|██████████| 50/50 [00:00<00:00, 154.73it/s]
# sampling time step: 100%|██████████| 50/50 [00:00<00:00, 156.07it/s]
# sampling time step: 100%|██████████| 50/50 [00:00<00:00, 156.59it/s]
